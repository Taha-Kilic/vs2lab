# %% [markdown]
# # Running server and client in a single notebook
# Note: not working with Windows
# ## Server part

# %%
import clientserver # import from our script
import os # os module needed for spawning another process

server = clientserver.Server() # Create a server instance
    
pid = os.fork() # we need to fork here in order not to block the notebook
if pid == 0: # run server in forked process
    server.serve() # start server routine in the forked process
    #os._exit(0) # after finisching the server routine, kill the forked process
# Out:
# 2026-04-11 23:17:49,496 - vs2lab.lab1.clientserver.Server - INFO - Server bound to socket <socket.socket fd=102, family=2, type=1, proto=0, laddr=('127.0.0.1', 50007)>
# /var/folders/8w/91lh3vp90mlfsm55ydxh9kbh0000gp/T/ipykernel_12950/3611956685.py:6: DeprecationWarning: This process (pid=12950) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   pid = os.fork() # we need to fork here in order not to block the notebook

# %% [markdown]
# ## Client
# Now create a client object and call the server

# %%
import clientserver # import from our script

client = clientserver.Client() # Create a client instance

print(client.get("Chris")) # get "Chris"
print(client.get("Alice")) # get "Alice"

print(client.get_all())
# Out:
# 2026-04-11 23:17:51,749 - vs2lab.a1_layers.clientserver.Client - INFO - Client connected to socket <socket.socket fd=88, family=2, type=1, proto=0, laddr=('127.0.0.1', 57999), raddr=('127.0.0.1', 50007)>
# 0721 333
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# Cell In[2], line 6
#       2
#       3 client = clientserver.Client() # Create a client instance
#       4
#       5 print(client.get("Chris")) # get "Chris"
# ----> 6 print(client.get("Alice")) # get "Alice"
#       7
#       8 print(client.get_all())
#
# File ~/vs2lab/lab1/clientserver.py:79, in Client.get(self, name)
#      77 def get(self, name):
#      78     self.sock.send(("GET " + name).encode('ascii'))
# ---> 79     data = self.sock.recv(1024)
#      80     #self.sock.close()
#      81     return data.decode('ascii')
#
# ConnectionResetError: [Errno 54] Connection reset by peer

# %% [markdown]
# That was all. The server process has terminated as well after returning the echo message.
